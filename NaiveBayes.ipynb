# %% [markdown]
# 1 - Importação das Bibliotecas que serão usadas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score

# %% [markdown]
# 2 - Carregamento dos dados

# %%
credito = pd.read_csv(r'F:\Estudando_Python\MachineLearn\Modelos_Preditivos\Credit.csv') # Carregando dados

# %% [markdown]
# 3 - Visualizar

# %%
credito.shape   # Vizualisar quantidade de linhas e colunas
# Out:
# (1000, 21)

# %%
credito.head()  # Visualizar os primeiros 5 registros
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
credito.describe() # Vizualiar informaçaões sobre o dataset
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %% [markdown]
# Separando Previsores da Classe

# %%
previsores = credito.iloc[:,0:20] ## Captura a Coluna zero até a 19 (20-1) que são os atributos
classe = credito.iloc[:,20]       ## Captura a Coluna 20

classe.head()
# Out:
# 0    good
# 1     bad
# 2    good
# 3    good
# 4     bad
# Name: class, dtype: str

# %% [markdown]
# Transformando Atributos Categóricos em Numéricos

# %%
previsores = previsores.astype(object)
for col in [0, 2, 3, 5, 6, 8, 9, 11, 13, 14, 16, 18, 19]:
    previsores.iloc[:, col] = LabelEncoder().fit_transform(previsores.iloc[:, col])

# %% [markdown]
# Divindo dados entre Testes e Treinamentos

# %%
x_treinamento, x_teste, y_treinamento, y_teste = train_test_split (
    previsores,
    classe,
    test_size = 0.3,
    random_state = 0
)

# %% [markdown]
# Criar e Treinar o Modelo

# %%
naive_bayes = GaussianNB() # Criar Modelo
naive_bayes.fit(x_treinamento, y_treinamento) # Treinar Modelo
# Out:
# GaussianNB()

# %% [markdown]
# Previsão

# %%
previsao = naive_bayes.predict(x_teste)
print(previsao)
# Out:
# ['bad' 'good' 'good' 'good' 'bad' 'good' 'good' 'good' 'good' 'bad' 'bad'
#  'bad' 'good' 'bad' 'good' 'good' 'good' 'good' 'bad' 'good' 'bad' 'good'
#  'bad' 'good' 'good' 'bad' 'good' 'good' 'good' 'bad' 'good' 'good' 'good'
#  'good' 'good' 'bad' 'good' 'good' 'good' 'good' 'good' 'bad' 'good'
#  'good' 'good' 'bad' 'bad' 'bad' 'bad' 'bad' 'good' 'bad' 'good' 'good'
#  'good' 'good' 'bad' 'good' 'good' 'good' 'bad' 'good' 'good' 'good'
#  'good' 'good' 'good' 'good' 'bad' 'good' 'good' 'good' 'good' 'good'
#  'bad' 'good' 'good' 'good' 'good' 'good' 'good' 'good' 'good' 'bad'
#  'good' 'good' 'bad' 'bad' 'good' 'bad' 'good' 'good' 'good' 'good' 'good'
#  'good' 'good' 'good' 'good' 'good' 'good' 'good' 'good' 'bad' 'good'
#  'good' 'bad' 'bad' 'good' 'good' 'good' 'bad' 'good' 'good' 'bad' 'good'
#  'good' 'good' 'good' 'bad' 'bad' 'good' 'good' 'bad' 'good' 'good' 'good'
#  'good' 'good' 'good' 'good' 'good' 'bad' 'good' 'good' 'good' 'good'
# ...

# %% [markdown]
# Matrix de Confusão

# %%
confusao = confusion_matrix(y_teste, previsao)
print(confusao)
# Out:
# [[ 41  45]
#  [ 42 172]]

# %% [markdown]
# Calcular Taxa de Acerto e Erro

# %%
taxa_de_acerto = accuracy_score(y_teste, previsao)
print("Acertos: ", taxa_de_acerto*100, "%" )
taxa_de_erro = 1 - taxa_de_acerto
print("Erros: ", taxa_de_erro*100, "%")
# Out:
# Acertos:  71.0 %
# Erros:  29.000000000000004 %
